# %% [markdown]
# <h3 style="text-align:center;">ESCUELA POLITÉCNICA NACIONAL</h3>
# <h3 style="text-align:center;">FACULTAD DE INGENIERÍA EN SISTEMAS</h3>
# <h3 style="text-align:center;">METODOS NUMERICOS ICCD412 </h3>
# <h3 style="text-align:center;">INFORME PROYECTO PRIMER BIMESTRE</h3>

# %% [markdown]
# * PAZMIÑO SALAZAR SEBASTIAN DANILO
# * PINTO ANDRANGO JUAN FRANCISCO
# * ULLOA CAIZAGUANO JESUS FRANCISCO
#
# * GRUPO-2
#
# * FECHA DE ENTREGA 25 DE NOVIEMBRE DEL 2025
#
# * Enlace de Repositorio de Git: https://github.com/Sebas-p2304/Metodos-Numericos/tree/main/ProyectoBim1_Grupo2
#
# * Enlace a Presentacion: https://www.canva.com/design/DAG5pE7PIu8/WzRMeEt-C_1y9TBNCNRGTA/edit?utm_content=DAG5pE7PIu8&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton

# %% [markdown]
# ### Descripción
# Un prestigioso banco lo ha contratado para implementar la calculadora de un programa de ahorro moderno.
# Este programa consiste de:
# * Un depósito inicial de al menos 50 dólares y
# * aportes semanales de al menos 5 dólares.
#
# Los técnicos del banco le han proporcionado la fórmula básica para calcular el interés compuesto:
#
# $V_f=V_o(1+i)^n$
# Donde:
# * $V_f$ es el valor final en la cuenta de ahorros,
# * $V_o$ es el valor de depósito inicial,
# * $i$ es la tasa de interés,
# * $n$ es el número de periodos transcuridos.
#
#
# Sin embargo, los técnicos del banco desconocen cómo se debe calcular los interes en base a los aportes semanales. Y en su lugar le han dado el siguiente ejemplo:
#
# ### Ejemplo
# Dado un depósito inicial de 100 dólares, aportes semanales de 5 dólares y una tasa de interés anual del 8%, la tabla de cálculo sería la siguiente:
#
# |  Semana  |  Aporte ($)  |  Capital ($)  |  Ganancia ($)  |  Total ($)  |
# |  ---     |         ---  |          ---  |           ---  |        ---  |
# |  1  |  100 |   100        |   0.15    |   100.15  |
# |  2  |  5   |   105.15     |   0.16    |   105.31  |
# |  3  |  5   |   110.31     |   0.17    |   110.48  |
# |  4  |  5   |   115.48     |   0.18    |   115.66  |
# |  5  |  5   |   120.66     |   0.19    |   120.85  |
# ...
# |  51  |  5  |   367.65     |   0.57    |   368.22  |
# |  52  |  5  |   373.22     |   0.57    |   373.79  |
#
#
# ### Objetivo
# Los técnicos del banco desean la calculadora para probar diferentes escenarios de ahorro, con el objetivo principal de determinar la tasa de **interés**.
#
# * Considere que el banco puede cambiar de opinión y pedirle que los aportes ya no sean semanales, sino mensuales, trimestrales o bimestrales. Incluya esta posibilidad en su programa.
#
# ### Instrucciones
# * Realice el desarrollo matemático necesario para determinar la fórmula de interés compuesto con aportes periódicos.
# * Implemente una interfaz gráfica GUI en Python que permita ingresar los parámetros iniciales (depósito inicial, aporte periódico, tasa de interés, periodo de aportes y duración del ahorro).
# * Su programa debe calcular y mostrar una tabla similar a la del ejemplo, pero adaptada a los parámetros ingresados.
# * Realice un análisis de la complejidad de la solución implementada, además de los recursos computacionales utilizados.
# * Realice una gráfica que muestre la evolución del total ahorrado a lo largo del tiempo.
# ### Parámetros de entrada
# * $V_o$ - Depósito inicial.
# * $V_f$ - Valor final deseado.
# * $A$ Aporte periódico.
# * Periodo de aportes (``semanal``, ``mensual``, ``bimestral``, ``trimestral``).
# * $n$ periodos de duración del ahorro (en semanas, meses, bimestres o trimestres, según el periodo de aportes seleccionado).
#
# ### Parámetro de salida
# * $i$ - Tasa de interés anual (en porcentaje).

# %% [markdown]
# ### Objetivos
#
# aplicar los conocimiento de metodos numericos en la solucion de problemas de la vida real haciendo uso de modelos matematicos que nos muestre una solucion matematica iterativa
#
#
# Determinar la tasa de interés requerida para alcanzar un capital acumulado específico mediante depósitos periódicos, resolviendo la ecuación de valor no lineal a través del método de bisección.

# %% [markdown]
# <h2 style="text-align:center;">Metodología</h2>
#
# <h3 style="text-align:center;">Desarrolo matematico</h3>
#
# <h3 style="text-align:center;"> Interés compuesto</h3>
#
#
#
# El interés compuesto se genera cuando los intereses generados en un período se suman al capital base, de modo que, en el siguiente período, se calculan nuevos intereses sobre el capital incrementado. Este proceso se repite periódicamente, provocando que el capital crezca de manera acelerada en comparación con el interés simple. La frecuencia con la que se generan estos intereses (mensual, trimestral, anual) afecta al capital final acumulado, ya que a mayor frecuencia de capitalización, mayor será el efecto acumulado.
#
#
# <h3 style="text-align:center;"> Depositos continuos</h3>
#
#
# En los depósitos continuos, el dinero se agrega al capital de la cuenta de manera constante, en lugar de realizar depósitos periódicos en intervalos fijos como ocurre en los depósitos mensuales. El interés compuesto continuo se describe con la fórmula:
#
# $A=Pe^rt$
#
# En esta fórmula, el interés se calcula de manera continua sobre el saldo acumulado, sin esperar a un período de capitalización específico. Esto permite una acumulación más fluida del interés a lo largo del tiempo.
#
# <h3 style="text-align:center;"> Metodo de la Bisección</h3>
#
#
# El método de la bisección se utiliza para encontrar la raíz de una función. En este escenario, lo implementamos para calcular la tasa de interés compuesto con aportes periódicos. Esto es necesario porque, para calcular la tasa de interés $i$ cuando conocemos el valor final $V_f$, el valor inicial $V_o$, y el número de períodos $n$, necesitamos resolver la siguiente ecuación:
#
# $V_f = V_o (1+i)^n$
#
# Debido a que trabajamos con una ecuación no lineal, no podemos resolverla de manera algebraica directa para $i$. Dado este escenario, utilizamos el método de bisección, que consiste en encontrar un intervalo en el que la función cambie de signo. El método divide repetidamente el intervalo a la mitad y evalúa la función en los puntos medios, ajustando el intervalo hasta encontrar una solución con la precisión requerida.
#
# Para implementar la calculadora de intereses, es necesario incluir una validación de los datos ingresados, asegurándonos de que tanto la tasa de interés como los períodos sean valores positivos. Además, debemos considerar la precisión de los cálculos, ya que, en ocasiones, el valor de $i$ puede converger lentamente o tener una precisión limitada debido al comportamiento del método de bisección.

# %% [markdown]
# 1) Modelo y convención
#
# Hay n periodos (por ejemplo n semanas).El depósito de la semana 1 es V0 (es decir, el primer aporte = V0).
# A partir de la semana 2 y hasta la n, cada semana aportas la misma cantidad A (constante).La secuencia de aportes es:
#  A1 = V0, A2 = A, A3 = A, ..., An = A.
#
# El interés i es la tasa periódica por semana (lo que queremos encontrar).El procedimiento que refleja tu tabla: en cada semana primero sumas el aporte y luego se aplica interés.Con esto, la recurrencia es:
#
# $𝑆0=0$
#
# $S_t= (S_t-1  + A_t)(1+i)$
#
# para t = 1,2,....,n
#
# y el valor final (al terminar periodo n) es
#
# VF = $S_n$
#
# 2) Forma cerrada (suma explícita)
#
# Desplegando la recurrencia se obtiene:
#
# $S_n=\sum_{k=1}^{n}A_k(1+i^n-k+1.)$
#
#
# Con tu patrón de aportes $A_1 = V_0 , A_k = A(k>=2):$
#
#
# $VF(i)=V_0(1+i)^n + \sum_{k=2}^{n} * A_k(1+i^n-k+1.)$
#
# la suma geométrica puede simplificarse si $i$ es diferente 0 a:
#
# $VF(i) = V_0 (1+i)^n + A*(\frac{((1+i)^n)-(1+i)}{i})*(1+i) $
#
#
# 3) Planteamiento para encontrar la tasa i
#
# Si conoces VF_dado (valor final observado), V0, A, n, defines la función objetivo:
#
# $F(i)=VF(i)-VF_dado$
#
# queremos encontrar la raíz $i$ tal que $f(i)=0$

# %% [markdown]
# <h3 style="text-align:center;">Descripción de la implementación, resaltando el método numérico utilizado</h3>
#
# La calculadora de tasa de interés anual realiza un enfoque numérico para calcular la tasa de interés necesaria para alcanzar un valor final específico en una cuenta de ahorros, comenzando con el valor del depósito inicial, los aportes periódicos y la duración del período de inversión.
#
# en la resolucion del problema usamos la formula para calcular el valor final $V_f$ con interés compuesto y aportes periódicos
#
# $V_f = V_o * (1+i)^n + A* ((1+i)^n  -1 / i)$
#
# donde
# - $V_f$: valor final esperado.
# - $V_o$: valor inicial del deposito.
# - $A$: aporte periodico.
# - $i$: tasa de interés por período.
# - $n$: número de períodos de inversión.
#
# * Metodo de Bisección
#
# Es un algoritmo que busca la raíz de una función en un intervalo. Para hallar la tasa de interés $i$ formulamos la función $g(i)$, que representa la diferencia entre el valor final calculado con una tasa $i$ y el valor deseado $V_f$.
#
# $g(i) = V_o * (1+i)^n + A ((1+i)^n - 1 /i) - V_f$
#
# el objetivo es encontrar el valor de $i$ tal que $g(i)=0$
#
# * implementacion del metodo de Bisección
#
# en nuestro código el algoritmo de la bisección sigue los siguientes pasos:
#
# * 1. Inicialización de valores: Asignamos un intervalo inicial para la tasa de interés, que puede ser positivo o negativo. Esto depende de la comparación inicial entre $ g(0) y V_f$. si $g(0)$ es menor que cero, buscamos una tasa postiva; si es mayor que cero buscamos una tasa negativa.
#
# * 2. Evaluación de la función: En cada iteración, se evalúa la función $g(i)$ en el punto medio del intervalo y se ajusta el intervalo dependiendo del signo de $g(i)$
#
#     - si $g(i)$ es negativo, significa que el valor final calculado es menor que $V_f$, por lo que se ajusta en el intervalo superior.
#
#     - so $g(i)$ es positivo el valor final calculado es mayor que $V_f$ por lo que se ajusta el intervalo inferior.
#
# * 3. Criterio de parada: El algoritmo continúa iterando hasta que la diferencia entre los extremos sea menor que un valor de tolerancia o hasta que la función evaluada en el punto medio sea lo suficientemente cercana a cero.
#
# * 4.Resultado: cuando el algoritmo finaliza, el valor de $i$ es el punto medio del intevalo final, que representa la tasa de interés que permite alcanzar el valor final esperado.

# %% [markdown]
# # Análisis analítico de estabilidad y convergencia del método implementado
#
# Análisis de la Convergencia en el Método de BisecciónEl método de bisección se caracteriza por una convergencia lineal, lo que implica que el error se reduce a la mitad en cada iteración.
#
# Aunque su velocidad es inferior a la de algoritmos de segundo orden como Newton-Raphson, su principal ventaja radica en su robustez: garantiza encontrar la solución siempre que la raíz se encuentre dentro del intervalo inicial.
#
# Esto lo hace idóneo para despejar variables complejas, como tasas de interés implícitas.Desde el punto de vista computacional, la precisión aumenta proporcionalmente al número de iteraciones ($N$), mejorando en un factor de 2 por ciclo.
#
# El algoritmo finaliza cuando la amplitud del intervalo o el valor de la función es menor a una tolerancia preestablecida (por ejemplo, $\epsilon = 10^{-6}$).

# %% [markdown]
# # PSEUDOCÓDIGO: CALCULADORA DE TASA DE INTERÉS ANUAL
#
# ## CONSTANTES Y CONFIGURACIÓN INICIAL
# ```
# ARCHIVO_JSON = "escenarios_ahorro.json"
# TOLERANCIA = 1e-12
# MAX_ITERACIONES_BISECCION = 300
# ```
#
# ---
#
# ## MÓDULO: PERSISTENCIA DE DATOS
#
# ### FUNCIÓN guardar_json(datos)
# ```
# INICIO
#     INTENTAR
#         Abrir ARCHIVO_JSON en modo lectura
#         Leer contenido y convertir a lista_escenarios
#     SI_ERROR (FileNotFoundError o JSONDecodeError)
#         lista_escenarios = []
#     FIN_INTENTAR
#
#     Agregar datos a lista_escenarios
#
#     Abrir ARCHIVO_JSON en modo escritura
#     Guardar lista_escenarios con formato indentado
#     Cerrar archivo
# FIN
# ```
#
# ---
#
# ## MÓDULO: CÁLCULOS FINANCIEROS
#
# ### FUNCIÓN vf_given_i(tasa_periodica, deposito_inicial, aporte_periodo, num_periodos)
# ```
# INICIO
#     saldo = 0.0
#
#     PARA t DESDE 1 HASTA num_periodos HACER
#         SI t == 1 ENTONCES
#             aporte_actual = deposito_inicial
#         SINO
#             aporte_actual = aporte_periodo
#         FIN_SI
#
#         saldo = (saldo + aporte_actual) × (1 + tasa_periodica)
#     FIN_PARA
#
#     RETORNAR saldo
# FIN
# ```
#
# ### FUNCIÓN f(tasa_periodica, deposito_inicial, aporte_periodo, num_periodos, valor_final_deseado)
# ```
# INICIO
#     resultado = vf_given_i(tasa_periodica, deposito_inicial, aporte_periodo, num_periodos)
#     RETORNAR resultado - valor_final_deseado
# FIN
# ```
#
# ### FUNCIÓN find_rate_bisection(V0, A, n, Vf, limite_inf=0.0, limite_sup=1.0, tolerancia=1e-12, max_iter=200)
# ```
# INICIO
#     INTENTAR
#         fa = f(limite_inf, V0, A, n, Vf)
#         fb = f(limite_sup, V0, A, n, Vf)
#     SI_ERROR
#         RETORNAR NULL
#     FIN_INTENTAR
#
#     // Expandir límite superior si no hay cambio de signo
#     contador_expansion = 0
#     MIENTRAS (fa × fb > 0) Y (contador_expansion < 50) HACER
#         limite_sup = limite_sup × 2
#         fb = f(limite_sup, V0, A, n, Vf)
#         contador_expansion = contador_expansion + 1
#     FIN_MIENTRAS
#
#     SI fa × fb > 0 ENTONCES
#         RETORNAR NULL  // No se encontró cambio de signo
#     FIN_SI
#
#     // Método de bisección
#     punto_medio = NULL
#     PARA iteracion DESDE 1 HASTA max_iter HACER
#         punto_medio = (limite_inf + limite_sup) / 2
#         fm = f(punto_medio, V0, A, n, Vf)
#
#         SI |fm| < tolerancia O (limite_sup - limite_inf)/2 < tolerancia ENTONCES
#             RETORNAR punto_medio
#         FIN_SI
#
#         SI fa × fm < 0 ENTONCES
#             limite_sup = punto_medio
#             fb = fm
#         SINO
#             limite_inf = punto_medio
#             fa = fm
#         FIN_SI
#     FIN_PARA
#
#     RETORNAR punto_medio
# FIN
# ```
#
# ---
#
# ## MÓDULO: LÓGICA PRINCIPAL
#
# ### FUNCIÓN calcular_tasa_y_tabla()
# ```
# INICIO
#     INTENTAR
#         // Leer datos de entrada
#         nombre = LEER(campo_nombre)
#         V0 = CONVERTIR_A_DECIMAL(campo_deposito_inicial)
#         Vf = CONVERTIR_A_DECIMAL(campo_valor_final)
#         A = CONVERTIR_A_DECIMAL(campo_aporte)
#         n = CONVERTIR_A_ENTERO(campo_duracion)
#         periodo = LEER(combo_periodo) en minúsculas
#
#         SI nombre está vacío ENTONCES
#             MOSTRAR_ERROR("Por favor ingresa un nombre de usuario")
#             RETORNAR
#         FIN_SI
#
#         // Determinar períodos anuales
#         SEGÚN periodo HACER
#             CASO "semanal": periodos_anuales = 52
#             CASO "mensual": periodos_anuales = 12
#             CASO "bimestral": periodos_anuales = 6
#             CASO "trimestral": periodos_anuales = 4
#             CASO_CONTRARIO:
#                 MOSTRAR_ERROR("Selecciona un periodo válido")
#                 RETORNAR
#         FIN_SEGÚN
#
#         // Buscar tasa periódica usando bisección
#         i_periodica = find_rate_bisection(V0, A, n, Vf, 0.0, 0.5, 1e-12, 300)
#
#         SI i_periodica == NULL ENTONCES
#             // Intentar con intervalo más amplio
#             i_periodica = find_rate_bisection(V0, A, n, Vf, -0.9, 5.0, 1e-12, 400)
#
#             SI i_periodica == NULL ENTONCES
#                 MOSTRAR_ERROR("No se encontró tasa válida. Revisa los datos")
#                 RETORNAR
#             FIN_SI
#         FIN_SI
#
#         // Calcular tasa anual efectiva
#         tasa_anual_efectiva = (1 + i_periodica)^periodos_anuales - 1
#         tasa_anual_porcentaje = tasa_anual_efectiva × 100
#
#         // Mostrar resultado de la tasa
#         MOSTRAR("Tasa de interés anual: " + tasa_anual_porcentaje + "%")
#
#         // Generar tabla de evolución
#         saldo_acumulado = 0.0
#         tabla_datos = []
#
#         PARA t DESDE 1 HASTA n HACER
#             SI t == 1 ENTONCES
#                 aporte_actual = V0
#             SINO
#                 aporte_actual = A
#             FIN_SI
#
#             capital = saldo_acumulado + aporte_actual
#             interes_ganado = capital × i_periodica
#             saldo_final = capital + interes_ganado
#
#             AGREGAR_A_TABLA(t, capital, aporte_actual, interes_ganado, saldo_final)
#
#             saldo_acumulado = saldo_final
#         FIN_PARA
#
#         // Actualizar tabla visual con estilo zebra
#         LIMPIAR_TABLA_VISUAL()
#
#         PARA CADA fila EN tabla_datos CON índice idx HACER
#             SI idx es par ENTONCES
#                 etiqueta = "oddrow"
#             SINO
#                 etiqueta = "evenrow"
#             FIN_SI
#
#             INSERTAR_EN_TABLA_VISUAL(fila con formato decimal, etiqueta)
#         FIN_PARA
#
#         // Generar gráfica
#         graficar_evolucion(tabla_datos, tasa_anual_porcentaje)
#
#         // Guardar escenario en JSON
#         datos_escenario = {
#             "usuario": nombre,
#             "deposito_inicial": V0,
#             "valor_final_deseado": Vf,
#             "aporte": A,
#             "periodo": periodo,
#             "duracion": n,
#             "tasa_interes_anual_%": REDONDEAR(tasa_anual_porcentaje, 6),
#             "tasa_periodica_i": REDONDEAR(i_periodica, 9)
#         }
#
#         guardar_json(datos_escenario)
#
#     SI_ERROR (ValueError)
#         MOSTRAR_ERROR("Ingresa valores numéricos válidos")
#     FIN_INTENTAR
# FIN
# ```
#
# ---
#
# ## MÓDULO: VISUALIZACIÓN
#
# ### FUNCIÓN graficar_evolucion(datos_tabla, tasa_anual)
# ```
# INICIO
#     // Extraer datos para gráfica
#     periodos = [fila[0] PARA cada fila EN datos_tabla]
#     saldos = [fila[4] PARA cada fila EN datos_tabla]
#
#     // Crear figura compacta
#     figura = CREAR_FIGURA(ancho=6, alto=3.5)
#     eje = CREAR_EJE(figura)
#
#     // Trazar línea de evolución
#     GRAFICAR_LINEA(eje, periodos, saldos, marcador="o", grosor=1.6)
#
#     // Configurar gráfica
#     ESTABLECER_TITULO(eje, "Evolución del saldo (Tasa anual " + tasa_anual + "%)")
#     ESTABLECER_ETIQUETA_X(eje, "Período")
#     ESTABLECER_ETIQUETA_Y(eje, "Saldo ($)")
#     MOSTRAR_CUADRICULA(eje, alpha=0.25)
#
#     // Línea de referencia en valor final
#     LINEA_HORIZONTAL(eje, saldos[último], estilo="--", etiqueta="Final = " + saldos[último])
#     MOSTRAR_LEYENDA(eje)
#
#     // Etiquetas opcionales en puntos
#     SI mostrar_etiquetas_activo ENTONCES
#         PARA CADA (x, y) EN (periodos, saldos) HACER
#             ANOTAR(eje, texto=y, posición=(x,y), desplazamiento=(0,2))
#         FIN_PARA
#     FIN_SI
#
#     // Limpiar y mostrar canvas
#     LIMPIAR_FRAME_GRAFICA()
#     canvas = CREAR_CANVAS(figura, frame_grafica)
#     DIBUJAR(canvas)
#     EMPAQUETAR(canvas)
#
#     // Controles debajo de la gráfica
#     frame_controles = CREAR_FRAME(frame_grafica)
#
#     boton_ampliar = CREAR_BOTON("Ver gráfica completa",
#                                  acción=mostrar_grafica_grande(periodos, saldos, tasa_anual))
#     EMPAQUETAR(boton_ampliar, lado="izquierda")
#
#     checkbox_etiquetas = CREAR_CHECKBOX("Mostrar etiquetas",
#                                          variable=mostrar_etiquetas,
#                                          acción=graficar_evolucion(datos_tabla, tasa_anual))
#     EMPAQUETAR(checkbox_etiquetas, lado="izquierda")
# FIN
# ```
#
# ### FUNCIÓN mostrar_grafica_grande(periodos, saldos, tasa_anual)
# ```
# INICIO
#     // Crear ventana emergente
#     ventana = CREAR_VENTANA_NUEVA()
#     ESTABLECER_TITULO(ventana, "Gráfica Ampliada")
#     ESTABLECER_TAMAÑO(ventana, 950, 700)
#
#     // Crear gráfica ampliada
#     figura = CREAR_FIGURA(ancho=9, alto=6)
#     eje = CREAR_EJE(figura)
#
#     GRAFICAR_LINEA(eje, periodos, saldos, marcador="o", grosor=2)
#     ESTABLECER_TITULO(eje, "Evolución del saldo (Tasa anual " + tasa_anual + "%)")
#     ESTABLECER_ETIQUETA_X(eje, "Período")
#     ESTABLECER_ETIQUETA_Y(eje, "Saldo ($)")
#     MOSTRAR_CUADRICULA(eje, alpha=0.25)
#     LINEA_HORIZONTAL(eje, saldos[último], estilo="--", etiqueta="Final = " + saldos[último])
#     MOSTRAR_LEYENDA(eje)
#
#     // Etiquetas si están activas
#     SI mostrar_etiquetas_activo ENTONCES
#         PARA CADA (x, y) EN (periodos, saldos) HACER
#             ANOTAR(eje, texto=y, posición=(x,y), desplazamiento=(0,2))
#         FIN_PARA
#     FIN_SI
#
#     // Mostrar canvas en ventana
#     canvas = CREAR_CANVAS(figura, ventana)
#     DIBUJAR(canvas)
#     EMPAQUETAR(canvas, llenar="ambos", expandir=verdadero)
# FIN
# ```
#
# ---
#
# ## MÓDULO: INTERFAZ GRÁFICA
#
# ### PROCEDIMIENTO inicializar_interfaz()
# ```
# INICIO
#     // Definir paleta de colores
#     COLOR_FONDO = "#F6F9FF"
#     COLOR_TARJETA = "#FFFFFF"
#     COLOR_ACENTO = "#2B6CB0"
#     COLOR_FILA_A = "#EAF2FF"
#     COLOR_FILA_B = "#FFFFFF"
#
#     // Crear ventana principal
#     ventana_principal = CREAR_VENTANA()
#     ESTABLECER_TITULO(ventana_principal, "Calculadora de Tasa de Interés Anual")
#     ESTABLECER_TAMAÑO(ventana_principal, 1000, 750)
#     PERMITIR_REDIMENSIONAR(ventana_principal, verdadero)
#     ESTABLECER_COLOR_FONDO(ventana_principal, COLOR_FONDO)
#
#     // Configurar estilos
#     estilo = CREAR_GESTOR_ESTILOS()
#     APLICAR_TEMA(estilo, "clam")
#
#     CONFIGURAR_ESTILO("TFrame", fondo=COLOR_FONDO)
#     CONFIGURAR_ESTILO("Card.TFrame", fondo=COLOR_TARJETA)
#     CONFIGURAR_ESTILO("TLabel", fondo=COLOR_FONDO, fuente=("Segoe UI", 10))
#     CONFIGURAR_ESTILO("Header.TLabel", fuente=("Segoe UI", 11, "negrita"))
#     CONFIGURAR_ESTILO("Accent.TLabel", color=COLOR_ACENTO, fuente=("Segoe UI", 10, "negrita"))
#
#     // Crear layout principal
#     frame_contenedor = CREAR_FRAME(ventana_principal, relleno=10)
#     EMPAQUETAR(frame_contenedor, llenar="ambos", expandir=verdadero)
#
#     // Panel izquierdo (formulario)
#     frame_izquierdo = CREAR_FRAME(frame_contenedor, estilo="Card.TFrame", relleno=12)
#     EMPAQUETAR(frame_izquierdo, lado="izquierda", llenar="y", margen_x=(0,10))
#
#     // Panel derecho (tabla y gráfica)
#     frame_derecho = CREAR_FRAME(frame_contenedor, estilo="Card.TFrame", relleno=12)
#     EMPAQUETAR(frame_derecho, lado="derecha", llenar="ambos", expandir=verdadero)
#
#     // --- FORMULARIO DE ENTRADA ---
#     CREAR_ETIQUETA(frame_izquierdo, "Calculadora de Ahorro", estilo="Header.TLabel")
#     POSICIONAR(fila=0, columna=0, columnas_fusionadas=2)
#
#     // Campo: Nombre
#     CREAR_ETIQUETA(frame_izquierdo, "Nombre del usuario:")
#     POSICIONAR(fila=1, columna=0, alineación="oeste")
#     campo_nombre = CREAR_CAMPO_TEXTO(frame_izquierdo, ancho=18)
#     POSICIONAR(campo_nombre, fila=1, columna=1)
#
#     // Campo: Depósito inicial
#     CREAR_ETIQUETA(frame_izquierdo, "Depósito inicial ($):")
#     POSICIONAR(fila=2, columna=0, alineación="oeste")
#     campo_deposito = CREAR_CAMPO_TEXTO(frame_izquierdo, ancho=18)
#     POSICIONAR(campo_deposito, fila=2, columna=1)
#
#     // Campo: Valor final deseado
#     CREAR_ETIQUETA(frame_izquierdo, "Valor final deseado ($):")
#     POSICIONAR(fila=3, columna=0, alineación="oeste")
#     campo_final = CREAR_CAMPO_TEXTO(frame_izquierdo, ancho=18)
#     POSICIONAR(campo_final, fila=3, columna=1)
#
#     // Campo: Aporte por período
#     CREAR_ETIQUETA(frame_izquierdo, "Aporte por período ($):")
#     POSICIONAR(fila=4, columna=0, alineación="oeste")
#     campo_aporte = CREAR_CAMPO_TEXTO(frame_izquierdo, ancho=18)
#     POSICIONAR(campo_aporte, fila=4, columna=1)
#
#     // Campo: Duración
#     CREAR_ETIQUETA(frame_izquierdo, "Duración (n períodos):")
#     POSICIONAR(fila=5, columna=0, alineación="oeste")
#     campo_duracion = CREAR_CAMPO_TEXTO(frame_izquierdo, ancho=18)
#     POSICIONAR(campo_duracion, fila=5, columna=1)
#
#     // Campo: Período de aporte
#     CREAR_ETIQUETA(frame_izquierdo, "Periodo de aporte:")
#     POSICIONAR(fila=6, columna=0, alineación="oeste")
#     combo_periodo = CREAR_COMBOBOX(frame_izquierdo,
#                                     valores=["Semanal", "Mensual", "Bimestral", "Trimestral"],
#                                     ancho=16)
#     POSICIONAR(combo_periodo, fila=6, columna=1)
#     SELECCIONAR_OPCION(combo_periodo, 0)
#
#     // Botón calcular
#     boton_calcular = CREAR_BOTON(frame_izquierdo,
#                                   "Calcular tasa y tabla",
#                                   acción=calcular_tasa_y_tabla)
#     POSICIONAR(boton_calcular, fila=7, columna=0, columnas_fusionadas=2, margen_y=(10,6))
#
#     // Etiqueta resultado
#     etiqueta_resultado = CREAR_ETIQUETA(frame_izquierdo, "", estilo="Accent.TLabel")
#     POSICIONAR(etiqueta_resultado, fila=8, columna=0, columnas_fusionadas=2)
#
#     // --- TABLA DE RESULTADOS ---
#     columnas_tabla = ("Periodo", "Saldo inicial", "Aporte", "Interés", "Saldo final")
#     tabla_resultados = CREAR_TABLA(frame_derecho, columnas=columnas_tabla, altura=10)
#
#     PARA CADA columna EN columnas_tabla HACER
#         ESTABLECER_ENCABEZADO(tabla_resultados, columna)
#         ESTABLECER_ANCHO(tabla_resultados, columna, 110)
#         ESTABLECER_ALINEACION(tabla_resultados, columna, "centro")
#     FIN_PARA
#
#     EMPAQUETAR(tabla_resultados, margen_y=10, llenar="x")
#
#     // Configurar estilos zebra
#     CONFIGURAR_ESTILO("Treeview",
#                       fondo=COLOR_FILA_A,
#                       alto_fila=24,
#                       fuente=("Segoe UI", 10))
#     CONFIGURAR_ETIQUETA_FILA(tabla_resultados, "oddrow", fondo=COLOR_FILA_A)
#     CONFIGURAR_ETIQUETA_FILA(tabla_resultados, "evenrow", fondo=COLOR_FILA_B)
#
#     // --- FRAME PARA GRÁFICA ---
#     frame_grafica = CREAR_FRAME(frame_derecho, estilo="Card.TFrame", relleno=6)
#     EMPAQUETAR(frame_grafica, llenar="ambos", expandir=verdadero)
#
#     // Pie de página
#     etiqueta_pie = CREAR_ETIQUETA(ventana_principal, "-EPN-")
#     EMPAQUETAR(etiqueta_pie, lado="abajo", margen_y=(2,6))
#
#     // Variable global para control de etiquetas
#     mostrar_etiquetas = CREAR_VARIABLE_BOOLEANA(valor=falso)
#
#     // Iniciar loop principal
#     EJECUTAR_LOOP_PRINCIPAL(ventana_principal)
# FIN
# ```
#
# ---
#
# ## PROGRAMA PRINCIPAL
# ```
# INICIO
#     inicializar_interfaz()
# FIN
# ```

# %% [markdown]
# <h2 style="text-align:center;">Resultados</h2>
#
# <h3 style="text-align:center;">Ejecución y descripción de diferentes casos de prueba.</h3>
#
# <h3 style="text-align:left;">Restricciones de Aporte Inicial: mínimo $50</h3>
#
# ![image.png](attachment:image.png)
#
# Restriccion solicitada en la descripción del Proyecto.
#
# <h3 style="text-align:left;">Restricciones de Aporte Periodico: mínimo $5</h3>
#
# ![image-2.png](attachment:image-2.png)
#
# Restriccion solicitada en la descripcion del proyecto
#
# <h3 style="text-align:left;">El numero "n" de periodos debe ser un entero positivo</h3>
#
# ![image-3.png](attachment:image-3.png)
#
# El numero de periodos mide una unidad de tiempo, por lo que no puede ser negativo.
#
# <h3 style="text-align:left;">El nombre de Usuario admite solo caracteres alfabeticos y vocales con acento</h3>
#
# ![image-4.png](attachment:image-4.png)
#
#
# <h3 style="text-align:left;">El valor final deseado debe ser mayor que el aporte inicial</h3>
#
# ![image-5.png](attachment:image-5.png)
#
# <h3 style="text-align:left;">Caso de prueba con los valores proporcionados por la descripcion del proyecto</h3>
#
# ![image-6.png](attachment:image-6.png)
#
# El objetivo de este caso de prueba es verificar el funcionamiento del proyecto con valores comprobados.
#
# <h3 style="text-align:left;">Caso de prueba con distintos periodos de aporte</h3>
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# Comprobar el funcionamiento del programa con distintos periodo de aporte, y contrastar los valores obtenidos. Teniendo un mejor entendimiento del desarrollo matematico del problema.
#
# <h3 style="text-align:left;">Caso Extremo: Aportes minimos, objetivo exageradamente grande</h3>
#
# ![image-10.png](attachment:image-10.png)
#
# Tratamos de estresar el algoritmo para verificar su robustez.
#
# <h3 style="text-align:left;"> Comparacion con Soluciones Analiticas</h3>
#
# Para el calculo de una tasa de interés desconocia no existe formula cerrada
#
# <h3 style="text-align:left;">Analisis de Resultados</h3>
#
# El análisis de resultados se enfocó en estudiar cómo los parámetros del ahorro influyen en la tasa de interés necesaria para alcanzar un valor final deseado, así como en el comportamiento del capital acumulado a lo largo del tiempo. Para ello, se ejecutaron múltiples escenarios variando la frecuencia de los aportes, el número de periodos, el aporte inicial y el monto periódico. A continuación, se presenta un desglose detallado de las observaciones obtenidas.
#
# 1) Influencia de la frecuencia del aporte en la tasa calculada
#
# Uno de los resultados más relevantes es que la frecuencia del aporte modifica significativamente la tasa de interés anual requerida:
#
# Aportes más frecuentes (semanales) generan un mayor número de capitalizaciones del aporte, lo que produce un crecimiento más rápido del capital.
#
# Esto implica que, para alcanzar el mismo valor final, la tasa de interés anual necesaria disminuye cuando los aportes son más frecuentes.
#
# En contraste, aportes más espaciados (mensuales, bimestrales, trimestrales) reducen la frecuencia con la que los aportes generan interés, por lo que la tasa requerida aumenta.
#
# Este comportamiento coincide con la teoría financiera: mayor periodicidad → mayor capitalización → menor necesidad de tasa anual.
#
# Gráficamente, se observa que las curvas correspondientes a mayor frecuencia presentan un crecimiento más suave pero constante y alcanzan el objetivo con menor pendiente efectiva.
#
# 2) Efecto del número de periodos en la estabilidad del resultado
#
# Al incrementar el número de periodos (n), manteniendo constante el valor final deseado, se evidenció que:
#
# La tasa de interés calculada experimenta menor variabilidad.
#
# Para valores grandes de n, pequeñas modificaciones en n no producen grandes variaciones en la tasa.
#
# Esto se debe a que el método de bisección opera sobre una función cada vez más suave a medida que se suman más aportes, lo que facilita la convergencia.
#
# En términos prácticos, con más periodos, la contribución de cada aporte individual es menor, lo cual reduce la sensibilidad del sistema frente a fluctuaciones pequeñas en la fórmula del valor final.
#
# 3) Efecto del aporte inicial V₀ sobre la tasa necesaria
#
# El aporte inicial V₀ cumple un rol clave:
#
# Un V₀ mayor reduce considerablemente la tasa necesaria, pues aporta capital que genera interés desde el primer periodo.
#
# En escenarios donde V₀ = 0, toda la carga de alcanzar el objetivo depende de los aportes periódicos, lo que obliga al programa a encontrar tasas más altas.
#
# El impacto es aún mayor cuando el horizonte temporal es corto: si n es pequeño y V₀ es significativo, la tasa requerida puede incluso acercarse a cero.
#
# Las gráficas muestran una diferencia notable entre curvas con V₀ > 0 y sin aporte inicial: en la primera, la curva despega más rápido, indicando un componente importante de rendimiento desde el inicio.
#
# 4) Transición entre aporte acumulado y rendimiento generado
#
# Los resultados muestran una transición progresiva entre la parte del capital que proviene del ahorro directo y la parte generada por el interés:
#
# En los primeros periodos predomina el aporte directo.
#
# Conforme avanza el tiempo, una porción creciente del total acumulado proviene del interés compuesto.
#
# Esta transición puede visualizarse claramente en las gráficas de evolución temporal, donde la curva se vuelve cada vez más inclinada (aceleración del crecimiento).
#
# Este fenómeno es más visible en escenarios de:
#
# tasas elevadas,
#
# largos horizontes (n grande),
#
# aportes periódicos significativos.
#
# <h3 style="text-align:left;"> Analisis de la Complejidad Computacional Experimental</h3>
#
# El cálculo de la tasa de interés se realizó utilizando el método de bisección, un algoritmo numérico robusto que garantiza convergencia siempre que la función sea continua y los extremos del intervalo presenten signos opuestos.
#
# 1) Complejidad teórica
#
# El método de bisección tiene complejidad:
#
# $O(log(1/\varepsilon)) $
#
# donde:
#
# - $\varepsilon$ Es la tolerancia deseada
# ε es la tolerancia deseada,
#
# - no depende directamente del número de periodos
# 𝑛
#
# Esto significa que el número de iteraciones aumenta de forma logarítmica al requerir mayor precisión, lo que lo hace muy eficiente.
#
# De las mediciones realizadas se concluye:
#
# - La complejidad crece muy poco con n, pues el algoritmo depende principalmente de la tolerancia.
#
# - El mayor costo computacional proviene de las evaluaciones repetidas de la fórmula de interés compuesto, especialmente cuando n es grande.
#
# - Aun así, la carga es mínima y la ejecución ocurre en milisegundos.
#
# Para propósitos prácticos, el método se considera: eficiente, escalable, adecuado para cualquier rango de periodos y parámetros.
#
# El desempeño observado es más que suficiente para aplicaciones educativas, financieras básicas o proyectos de simulación como el desarrollado.

# %% [markdown]
# <h2 style="text-align:center;">Conclusiones</h2>
#
# <h3 style="text-align:left;">Resumen de los hallazgos más importantes.</h3>
#
# A lo largo del desarrollo y experimentación del proyecto, se obtuvieron varios resultados significativos:
#
# - El programa calcula correctamente la tasa de interés necesaria para alcanzar un valor final deseado bajo diferentes combinaciones de parámetros (depósito inicial, aportes periódicos, duración y tipo de periodo).
#
# - La herramienta mostró ser flexible y robusta ante cambios del periodo de aportes, permitiendo trabajar sin problemas con modalidades semanal, mensual, bimestral y trimestral.
#
# - La generación automática de tablas detalladas y gráficas facilita enormemente la comprensión del proceso de acumulación de capital, evidenciando de forma visual la interacción entre aportes e intereses.
#
# - El método numérico empleado (bisección) demostró estabilidad y convergencia rápida, incluso bajo escenarios exigentes con muchos periodos o valores extremos.
#
# - Se verificó coherencia entre los resultados numéricos obtenidos, la teoría del interés compuesto y las expectativas esperadas según modelos financieros tradicionales.
#
# En conjunto, el sistema desarrollado constituye una herramienta confiable y didáctica para analizar escenarios de ahorro e interés compuesto.
#
# <h3 style="text-align:left;"> Dificultades encontradas y como se resolvieron</h3>
#
# - En un principio existia inconsistencia entre los datos obtenidos en la tabla generada, al compararlos con los datos de la tabla de ejemplo. Se corrigio al realizar un analisis y desarrollo matematico mas profundo.
#
# - Inconsistencias entre la tasa anual y la tasa periódica, especialmente al comparar escenarios entre diferentes frecuencias de aporte.
#
# Se unificó la fórmula usando siempre la tasa anual efectiva como valor central, asegurando consistencia y precisión.
#
# <h3 style="text-align:left;"> Limitaciones y Restricciones</h3>
#
# A pesar de su funcionalidad, el proyecto presenta algunas limitaciones inherentes al modelo propuesto:
#
# - El método de bisección, aunque garantiza convergencia, no es tan rápido como otros métodos (Newton-Raphson, secante) cuando se dispone de derivadas.
#
# - Solo se consideran aportes periódicos iguales por exigencia del proyecto; no permite aportes escalonados o variables.
#
# - No se toman en cuenta factores reales como inflación, impuestos, comisiones bancarias, riesgo financiero, ni cambios de tasa durante el tiempo.
#
# - El modelo trabaja exclusivamente con una tasa fija, lo cual no siempre se ajusta a productos financieros reales.
#
# - No se permite ingresar aportes extraordinarios ni retiros parciales, lo cual reduce el realismo de ciertos escenarios complejos.
#
# Estas restricciones no afectan el correcto funcionamiento del programa, pero sí delimitan el tipo de análisis financiero que puede realizarse.
#
# <h3 style="text-align:left;"> Posibles Mejoras</h3>
#
# Para ampliar el alcance, eficiencia y utilidad del programa, se proponen las siguientes mejoras futuras:
#
# - Implementar métodos numéricos más rápidos, como Newton-Raphson , para reducir el número de iteraciones requeridas.
#
# - Permitir aportes personalizados, ya sea crecientes, decrecientes o no uniformes.
#
# - Incorporar tasas variables por tramos (por ejemplo, diferentes tasas cada año o cada trimestre).
#
# - Mejorar la interfaz gráfica empleando herramientas más interactivas como Plotly, Dash o Tkinter avanzado con animaciones.
#
# - Habilitar la opción de exportar resultados avanzados a Excel, PDF o gráficos en alta resolución.
#
# - Incluir un comparador de escenarios que permita graficar múltiples curvas simultáneamente para analizar diferencias en tasas, periodos o aportes.
#
# - Agregar un simulador de inflación o riesgo, útil para contextos reales donde la tasa nominal no refleja necesariamente el poder adquisitivo final.
#
# Estas mejoras permitirían transformar el proyecto en una herramienta más completa, profesional y adaptable a estudios financieros avanzados.
